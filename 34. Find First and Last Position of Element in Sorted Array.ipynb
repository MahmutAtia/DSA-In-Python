# %%
    def searchRange(nums, target) :
        l = 0
        r = len(nums)-1


        while l<r:
            mid = (l+r) // 2
            print(l,r)
            print(mid)
            if nums[mid] < target:
                l= mid+1
            elif nums[mid] > target:
                r = mid-1

            elif nums[mid] == target:
                break

            else:
                return [-1,-1]

        # we found the target number
        idx_l = mid
        idx_r = mid

        left,right = True , True
        while left or right :
            print(idx_l,idx_r)
            if nums[idx_l-1] == nums[mid]:
                idx_l-=1
            else:
              left = False

            if nums[idx_r+1] == nums[mid]:
                idx_r += 1

            else:
              right = False



        return [idx_l,idx_r]

# %%
(3+5) //2
# Out:
# 4

# %% [markdown]
# Try 2:

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        l = 0
        r = len(nums)-1
        mid = 0

        #edge cace
        if nums == []:
            return [-1,-1]

        while l<r:
            mid = (l+r) // 2
            print(l,r)
            print(mid)
            if nums[mid] < target:
                l= mid+1
            elif nums[mid] > target:
                r = mid-1

            else:
                break




        #edge cace
        if mid == 0 and not nums[mid]== target:
            return [-1,-1]
        # we found the target number
        idx_l = mid
        idx_r = mid

        left,right = True , True
        while left or right :
            print(idx_l,idx_r)
            if len(nums[:idx_l])> 1 and nums[idx_l-1] == nums[mid]:
                idx_l-=1
            else:
              left = False

            if len(nums[idx_r:])> 1 and nums[idx_r+1] == nums[mid]:
                idx_r += 1

            else:
              right = False



        return [idx_l,idx_r]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-899e8f4d4efa> in <cell line: 1>()
# ----> 1 class Solution:
#       2     def searchRange(self, nums: List[int], target: int) -> List[int]:
#       3         l = 0
#       4         r = len(nums)-1
#       5         mid = 0
#
# <ipython-input-1-899e8f4d4efa> in Solution()
#       1 class Solution:
# ----> 2     def searchRange(self, nums: List[int], target: int) -> List[int]:
#       3         l = 0
#       4         r = len(nums)-1
#       5         mid = 0
#
# NameError: name 'List' is not defined

# %% [markdown]
# try 3 : Accepted bet i dont like it

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        l = 0
        r = len(nums)-1
        mid = 0

        #edge cace
        if nums == []:
            return [-1,-1]

        while l<=r:
            mid = (l+r) // 2

            if nums[mid] < target:
                l= mid+1
            elif nums[mid] > target:
                r = mid-1

            else:
                break



        #edge cace
        if nums[mid]!= target:
            return [-1,-1]

        # we found the target number
        idx_l = mid
        idx_r = mid

        left,right = True , True
        while left or right :
            if len(nums[:idx_l])>= 1 and nums[idx_l-1] == nums[mid]:
                idx_l-=1
            else:
              left = False

            if len(nums[idx_r:])> 1 and nums[idx_r+1] == nums[mid]:
                idx_r += 1

            else:
              right = False



        return [idx_l,idx_r]

# %%
nums = [5,7,7,8,8,10]
searchRange(nums,6)
# Out:
# 0 5
# 2
# 0 1
# 0
# 0 0
# [0, 0]
