# %% [markdown]
# Try Number 1 : Success 223 / 987

# %%
def lengthOfLongestSubstring( s: str) -> int:
  out = 0
  temp = ""
  temps = []
  for idx,ch in  enumerate(s):
    if ch not in temp:
      print(ch)
      temp+= ch

      # if there is only one charchter
      if len(temp) == len(s) :
        out = len(temp)

      # if the bigger substring at the end
      if idx == len(s)-1:
        out = max(out,len(temp))
        temps.append(temp)

    else:
      temps.append(temp)
      if len(temp) > out:

        out = len(temp)

        #to add the previos charachters
        temp_start_idx = 0
        print(temp[temp_start_idx] ,ch,)
        while temp[temp_start_idx] != ch:
          print(temp)
          temp_start_idx +=1




        temp = temp[temp_start_idx+1 :] + ch

  print(temps)
  return out

# %% [markdown]
# Try number 2

# %%
def lengthOfLongestSubstring( s: str) -> int:
  out = 0
  temp = ""
  temps = []
  i = 0
  while i <  len(s):
    if s[i] not in temp:
      temp+= s[i]

      # if there is only one charchter
      if len(temp) == len(s) :
        out = len(temp)

      # if the bigger substring at the end
      if i == len(s)-1:
        out = max(out,len(temp))
        temps.append(temp)

    else:
      temps.append(temp)
      if len(temp) > out:

        out = len(temp)

        #to add the previos charachters
        temp_start_idx = 0
        print(temp[temp_start_idx] ,s[i])
        while temp[temp_start_idx] != s[i]:
          print(temp)
          temp_start_idx +=1





        print(i,len(temp),temp_start_idx)
        i = i-(len(temp) - temp_start_idx-1)
        temp = ""


    i +=1

  print(temps)
  return out

# %% [markdown]
# Try Number 3 :** BEST SOLUTION**

# %%
def lengthOfLongestSubstring( s: str) -> int:

  out = 0
  temp = ""
  p = 0

  while p < len(s):
    if s[p] not in temp:
      temp += s[p]
      p+=1
      # if there is only one charchter
      if len(temp) == len(s) :
        out = len(temp)

      # if the bigger substring at the end
      if p == len(s)-1:
        out = max(out,len(temp))




    else:
      print(temp)
      out = max(out,len(temp))
      idx = 0
      while temp[idx] != s[p]:
        idx+=1
        print(idx)


      temp = temp[idx+1 :] + s[p]
      p+=1

  return out

# %%
s = "jbpnbwwd"


lengthOfLongestSubstring(s)
# Out:
# jbpn
# 1
# pnbw
# 1
# 2
# 3
# 4

# %%
s= " "
len(s)
# Out:
# 1

# %%
s = "dvdf"
s[6:]
# Out:
# 'asd'
