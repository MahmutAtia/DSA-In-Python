# %% [markdown]
# Try 1:

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li = self.adj_li(numCourses,prerequisites)
        print(adj_li)
        return self.dfs(adj_li)

    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        for pre in prerequisites:
            i = pre[1] # the prequisite , the head
            child = pre[0]
            adj_li[i].append(child)
        return adj_li

    def dfs(self,adj_li):
        seen = {}

        for pre,courses in enumerate(adj_li):
            seen[pre] = True
            for course in courses:

                for i in adj_li[course]:
                    if seen.get(i):
                        print(i)
                        return False

        return True

# %% [markdown]
# Try 2

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li = self.adj_li(numCourses,prerequisites)

        out = True
        for i in range(len(adj_li)):
            out = self.dfs(i,adj_li) and out
        return out

    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        for pre in prerequisites:
            i = pre[1] # the prequisite , the head
            child = pre[0]
            adj_li[i].append(child)
        return adj_li

    def dfs(self,node,adj_li):
        seen = {}
        if seen.get(node):
            return False

        seen[node] = True
        nodes = adj_li[node]
        for node in nodes:

                self.dfs(node,adj_li)



        return True

# %% [markdown]
# try 3

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li = self.adj_li(numCourses,prerequisites)


        # bfs
        for i in range(len(adj_li)):
            q = [i]
            seen = {}
            while q:
                print(q)
                curr=q.pop(0)
                if seen.get(curr):
                    return False

                nodes = adj_li[curr]
                for node in nodes:
                    if not seen.get(node):
                        q.append(node)

        return True


    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        for pre in prerequisites:
            i = pre[1] # the prequisite , the head
            child = pre[0]
            adj_li[i].append(child)
        return adj_li

    def dfs(self,node,adj_li):
        seen = {}
        if seen.get(node):
            return False

        seen[node] = True
        nodes = adj_li[node]
        for node in nodes:

                self.dfs(node,adj_li)



        return True

# %% [markdown]
# Working with time limit , there something i couldnt understand

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li = self.adj_li(numCourses,prerequisites)

        print(adj_li)
        # bfs

        for i in range(len(adj_li)):
            # print("new for loop whith i = ", i)
            q = []
            seen = {}
            for  node in adj_li[i]:
                q.append(node)
            while q:
                # print(q)
                curr=q.pop(0)
                seen[curr] = True
                # print(i,curr)

                nodes = adj_li[curr]

                for node in nodes:
                    if i == curr:
                        return False

                    #if not seen.get(curr):
                    q.append(node)

        return True


    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        for pre in prerequisites:
            i = pre[1] # the prequisite , the head
            child = pre[0]
            adj_li[i].append(child)
        return adj_li

    def dfs(self,node,adj_li):
        seen = {}
        if seen.get(node):
            return False

        seen[node] = True
        nodes = adj_li[node]
        for node in nodes:

                self.dfs(node,adj_li)



        return True

# %% [markdown]
# try 5

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li , ndeg= self.adj_li(numCourses,prerequisites)
        print(adj_li , ndeg)

        if 0 not in ndeg:
            return False

        new_ndeg = self.ts(adj_li,ndeg)

        for i in ndeg:
            if i > 0:
                return False
        return True



    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        ndeg = [0 for _ in range(num)]


        for pre in prerequisites:
            i = pre[0] # the prequisite , the head
            child = pre[1]
            ndeg[child] += 1 # new degree added
            adj_li[i].append(child)



        return adj_li ,ndeg




    def ts(self,adj,ndeg):
        seen = {}
        # Topological sort
        while True:
            ndeg_b_for = ndeg.copy()
            for i,deg in enumerate(ndeg):
                if deg ==0:
                    node_0_deg = i
                    self.decrement_deg(adj,ndeg,node_0_deg)
            if ndeg == ndeg_b_for:
                break
        return ndeg
    def decrement_deg(self,adj,ndeg,node_0_deg):
        for node in adj[node_0_deg]:
            ndeg[node]-=1

# %% [markdown]
# Try 6 : Accepted

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li , ndeg= self.adj_li(numCourses,prerequisites)
        # print(adj_li , ndeg)

        if 0 not in ndeg:
            return False

        stack = []
        for i,deg in enumerate(ndeg):
            if deg == 0:
                stack.append(i)

        while stack:
            node_with_0_deg = stack.pop()
            for node_has_connect in adj_li[node_with_0_deg] :
                    ndeg[node_has_connect] -=1
                    if ndeg[node_has_connect] == 0:
                        stack.append(node_has_connect)

        for i in ndeg:
            if i > 0:
                return False
        return True
    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        ndeg = [0 for _ in range(num)]


        for pre in prerequisites:
            i = pre[0] # the prequisite , the head
            child = pre[1]
            ndeg[child] += 1 # new degree added
            adj_li[i].append(child)



        return adj_li ,ndeg

# %% [markdown]
# Using Count

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        adj_li , ndeg= self.adj_li(numCourses,prerequisites)
        # print(adj_li , ndeg)

        if 0 not in ndeg:
            return False

        stack = []
        for i,deg in enumerate(ndeg):
            if deg == 0:
                stack.append(i)
        count = 0
        while stack:
            count+=1
            node_with_0_deg = stack.pop()
            for node_has_connect in adj_li[node_with_0_deg] :
                    ndeg[node_has_connect] -=1
                    if ndeg[node_has_connect] == 0:
                        stack.append(node_has_connect)

        if count<len(ndeg):
                return False
        return True
    def adj_li(self,num,prerequisites):
        adj_li  = [[] for _ in range(num)]
        ndeg = [0 for _ in range(num)]


        for pre in prerequisites:
            i = pre[0] # the prequisite , the head
            child = pre[1]
            ndeg[child] += 1 # new degree added
            adj_li[i].append(child)



        return adj_li ,ndeg
