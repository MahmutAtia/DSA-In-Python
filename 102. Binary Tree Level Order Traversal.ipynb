# %% [markdown]
# Try 2:

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        if not root:
            return []

        queue = []
        out = [[root.val]]

        queue.append([root]) # is a level of nodes
        while len(queue) > 0:
            li_of_node = queue.pop(0) # frist in frist out
            li = [] # level values
            while len(li_of_node) > 0:
                li_of_nodes = []


                node = li_of_node.pop(0)
                print("node is :  ", node.val)

                if node.left:
                    li_of_nodes.append(node.left)
                    print("left is :  ", node.left.val)

                    li.append(node.left.val)
                if node.right:
                    li_of_nodes.append(node.right)
                    print("right is :  ", node.right.val)

                    li.append(node.right.val)


            queue.append(li_of_nodes)
            li_of_nodes = []

        if li: # if there are children
            out.append(li) # push level
            li = [] # reset li for new level
        return out

# %% [markdown]
# Try 3 : Accepted

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        if not root:
            return []

        queue = []
        out = []
        queue.append(root)
        while len(queue) > 0:
            li = [] # list of the level
            count = 0 # count of which is poped
            lenght = len(queue) # 2 3

            while count < lenght:
                print("count and len is : ", count,lenght)


                node = queue.pop(0) # frist in frist out
                li.append(node.val)

                if node.left:
                    queue.append(node.left)

                if node.right:
                    queue.append(node.right)


                count += 1
            print(li)
            out.append(li) # push level

        return out
