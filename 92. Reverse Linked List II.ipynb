# %% [markdown]
# Try Number 1:

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
 def reverseBetween(self, head, left: int, right: int) :


    cn = head
    indx = 1
    left_node = None
    prev = head
    out = cn
    while cn != None:
        next_n = cn.next
        print(out.val,indx)
        #check for left
        if indx+1 == left:
            left_node = cn
            right_node = self.find_right_node(cn,indx,right)
            out.next = right_node

        elif indx+1 == right:
            out.next = left

        else:
            out.next = cn.next # if there is no change

        print(out.next)

        cn = next_n
        indx +=1

    return out



 def find_right_node(self,head,indx , right_index):
        cn = head
        while cn != None:
            next_n = cn.next

            #check for the index of the node
            if indx == right_index:
                return cn
            cn = next_n
            indx+=1

# %%
li = ListNode(1)
n2 = ListNode(2)
n3 = ListNode(3)
n4 = ListNode(4)
n5 = ListNode(5)
n6 = ListNode(6)
n7 = ListNode(7)
li.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6
n6.next = n7

# %%
sol = Solution()
out_li = sol.reverseBetween(li,2,4)
# Out:
# 1 1
# ...
# 1 2
# ...
# 1 3
# 2
# 1 4
# ...
# 1 5
# ...
# 1 6
# ...
# 1 7
# None

# %% [markdown]
# Try Number 2:

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
 def reverseBetween(self, head, left: int, right: int) :


    cn = head
    left_node = None
    prev = head
    out = cn
    li = []
    while cn != None:
        next_n = cn.next
        li.append(cn.val)
        cn = next_n


    # update left and right nodes
    left_node = li[left-1]
    li[left-1] = li[right-1]
    li[right-1] = left_node

    head = None
    next = None
    for i in range(len(li)):
      print(i)
      if i == 0:
        head = ListNode(li[i])

      else :
        next = head
        node = ListNode(li[i])
        next.next = node
        next = next.next



    return li , next

# %% [markdown]
# Try Number 3:

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseBetween(self, head,left: int, right: int) :


      new_sli = None

      cn = head # first node

      idx = 1

      while cn  != None:
        print(idx)

        next = cn.next # Cut the refrence
        if left-1 == idx-1 : # reverse logic

           prev , new_idx = self.reverse(cn,idx,right)

           #adding the reversed head to last node
           new_sli = self.add_to_last_node(new_sli,prev)
           # update index after reaching right
           idx = new_idx

           cn = next
           idx +=1


        else:

          if idx == 1:
            new_sli = cn

          else:
            new_sli = self.add_to_last_node(new_sli,cn)

        cn = next
        idx +=1

      return new_sli
    def reverse(self,head, idx, right):
        cn = head
        prev = None
        next = None

        while  idx <= right:
          print(idx)
          next = cn.next #new refrance

          # How can i return the same list
          cn.next = prev
          prev = cn
          cn = next
          idx+=1

        return prev,idx

    def add_to_last_node(self,head,node):
        last_node = head
        while last_node.next != None:
          last_node = last_node.next
        last_node.next = node
        return head

# %% [markdown]
# Try Number 4:

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseBetween(self, head,left: int, right: int) :

      # loop untill finding where to start to revers
      idx = 1
      start = head
      cn = head
      while  idx < left:
        idx +=1
        start = cn
        cn = cn.next



      # reverse
      tail = cn
      new_li = None
      while idx <= right:

        next = cn.next
        cn.next = new_li
        new_li = cn

        cn = next
        idx+=1

      print(tail.val, print(cn.val))
      start.next = new_li
      tail.next = cn
      print(tail.val, print(cn.val))

      return head

# %%
li = ListNode(1)
n2 = ListNode(2)
n3 = ListNode(3)
n4 = ListNode(4)
n5 = ListNode(5)
n6 = ListNode(6)
n7 = ListNode(7)
li.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
n5.next = n6
n6.next = n7

# %%
sol = Solution()

out_prev = sol.reverseBetween(li,3,4)
# test,idx = sol.reverse(li,1,4)
# Out:
# 5
# 3 None
# 5
# 3 None

# %%
next = out_prev
new = ListNode(1)
for i in range(8):
  print(next.val)


  next = next.next
# Out:
# 1
# 2
# 4
# 3
# 5
# 6
# 7
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-963a4791ba3c> in <cell line: 3>()
#       2 new = ListNode(1)
#       3 for i in range(8):
# ----> 4   print(next.val)
#       5
#       6
#
# AttributeError: 'NoneType' object has no attribute 'val'
