# %%
class Solution(object):
    def sortByBits(self, arr):
        """
        :type arr: List[int]
        :rtype: List[int]
        """

        self.quick_sort(arr,0,len(arr)-1)
        return arr

    def quick_sort(self,arr,l,r):
        i , j = l,l
        print(r)
        print(arr)
        piviot = arr[r]

        while j<r:
            if self.count_1(arr[j]) <self.count_1(piviot):
                self._swap(arr,i,j)
                i+=1



            elif  self.count_1(arr[j]) == self.count_1(piviot):
                if arr[j] < piviot:
                    self._swap(arr,i,j)
                    i+=1
            j+=1


        # swap the piviot
        #piviot == arr[j]

        self._swap(arr,i,j)


        left = arr[:i]   # here was the problem
        right = arr[i:]
        print(len(left),len(right))

        if len(left)>1:
            self.quick_sort(arr,l,i-1)
        if len(right)>1:
            self.quick_sort(arr,i+1,r)




    def _swap(self,arr,i,j):
        temp = arr[i]
        arr[i] = arr[j]
        arr[j] = temp

    def count_1(self,num):
        if num == 0:
            return 0
        temp = num
        binery = ""
        while True:
           dig =  num % 2
           binery+=str(dig)
           num = num // 2
           if num == 0 and dig == 1:
               break
            # binery[: : -1]

        return binery.count("1")

# %%
class Solution(object):
    def sortByBits(self, arr):
        """
        :type arr: List[int]
        :rtype: List[int]
        """

        self.quick_sort(arr,0,len(arr)-1)
        return arr

    def quick_sort(self,arr,l,r):
        i , j = l,l

        piviot = arr[r]

        while j<r:
            if self.count_1(arr[j]) <self.count_1(piviot):
                self._swap(arr,i,j)
                i+=1



            elif  self.count_1(arr[j]) == self.count_1(piviot):
                if arr[j] < piviot:
                    self._swap(arr,i,j)
                    i+=1
            j+=1


        # swap the piviot
        #piviot == arr[j]

        self._swap(arr,i,j)


        left = i-l
        right = (r+1)-(i+1) # to get the true length

        if left>1:
            self.quick_sort(arr,l,i-1)
        if right>1:
            self.quick_sort(arr,i+1,r)




    def _swap(self,arr,i,j):
        temp = arr[i]
        arr[i] = arr[j]
        arr[j] = temp

    def count_1(self,num):
        if num == 0:
            return 0
        temp = num
        binery = ""
        while True:
           dig =  num % 2
           binery+=str(dig)
           num = num // 2
           if num == 0 and dig == 1:
               break
            # binery[: : -1]

        return binery.count("1")

# %%
sorted(li1, key= lambda x: bin(x).count("1")  )
# Out:
# [1, 2, 4, 8, 3, 5, 6, 7]

# %%
student_tuples = [
    ('john', 'A', 15),
    ('jane', 'C', 12),
    ('dave', 'B', 15),
]
sorted(student_tuples, key=lambda student: student[2])   # sort by age
# Out:
# [('jane', 'C', 12), ('john', 'A', 15), ('dave', 'B', 15)]

# %%
count_1(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-da121de7ac68> in <cell line: 1>()
# ----> 1 count_1(0)
#
# <ipython-input-14-1477b9ba063a> in count_1(num)
#       6        binery+=str(dig)
#       7        num = num // 2
# ----> 8        if num == 0 and dig == 1:
#       9            break
#      10         # binery[: : -1]
#
# KeyboardInterrupt:
