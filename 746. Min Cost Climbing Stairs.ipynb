# %% [markdown]
# Try 1:

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        i = len(cost)
        return min(self.min_cost(cost,i-1),self.min_cost(cost,i-2))

    def min_cost(self,cost,i):


        # print(cost[i],i)
        if i<0:
            return 0
        if i == 0 or i == 1:
            return  cost[i]
        return cost[i] +  min(self.min_cost(cost,i-1),self.min_cost(cost,i-2))

# %% [markdown]
# Memoization : Accepted

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        i = len(cost)
        min_costs = [False for _ in cost]
        return min(self.min_cost(cost,i-1,min_costs),self.min_cost(cost,i-2,min_costs))

    def min_cost(self,cost,i,min_costs):


        # print(cost[i],i)
        if i<0:
            return 0
        if i == 0 or i == 1:
            return  cost[i]
        if not min_costs[i-1]:
            min_costs[i-1] = self.min_cost(cost,i-1,min_costs)
        if not min_costs[i-2]:
            min_costs[i-2]= self.min_cost(cost,i-2,min_costs)
        return cost[i] +  min(min_costs[i-1],min_costs[i-2])

# %% [markdown]
# course solution mines was faster

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        i = len(cost)
        min_costs = [0 for _ in cost]
        return min(self.min_cost(cost,i-1,min_costs),self.min_cost(cost,i-2,min_costs))

    def min_cost(self,cost,i,min_costs):


        # print(cost[i],i)
        if i<0:
            return 0
        if i == 0 or i == 1:
            return  cost[i]

        if not min_costs[i]:
         min_costs[i] = cost[i] +  min(self.min_cost(cost,i-1,min_costs),self.min_cost(cost,i-2,min_costs))

        return min_costs[i]

# %% [markdown]
# Best Answer bottom up

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        #bottom up

        min_cost = [None for _ in range(len(cost))]
        for i in range(len(cost)):
            if i < 2:
                min_cost[i] = cost[i]

            else:
                min_cost[i] = cost[i] + min(min_cost[i-1],min_cost[i-2])

        return min(min_cost[-1],min_cost[-2])

# %% [markdown]
# Best Answer Ever

# %%
lass Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        #bottom up
        one = cost[0]
        two = cost[1]
        for i in range(2,len(cost)):

            current = cost[i]  + min(one,two)
            one = two
            two = current


        return min(one,two)
