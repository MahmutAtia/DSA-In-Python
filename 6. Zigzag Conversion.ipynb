# %%
class Solution(object):
    def convert(self, s, numRows):
        """
        :type s: str
        :type numRows: int
        :rtype: str
        """
        grid = self.get_grid(s, numRows)
        print(len(grid),len(grid[0]))
        print(grid)


        return s
    def get_grid(self,s,rows):
        one_zigzag = rows + (rows-2) # colums in one zig
        if len(s)> one_zigzag and one_zigzag != 0:
            # print(len(s), one_zigzag)
            num_of_zigzags = len(s)//one_zigzag
            remain = len(s) % one_zigzag

            cols = (1 + rows-2) * num_of_zigzags

            if remain <= rows:
                cols+=1
            else:
                col+=1
                cols+= (remain-4)
        else:
            cols = one_zigzag


        return [[None]*cols for _ in range(rows)]
