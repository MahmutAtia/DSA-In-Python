# %% [markdown]
# Try num 1

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def countNodes(self, root: Optional[TreeNode]) -> int:

        return self.recursive(root)


    def recursive(self,node, count = -1, max_c=-1,num = 0):

        if not node :
            if count > max_c:

                return (2 *  count)+1
        count+=1
        max_c = max(max_c,count)


        return self.recursive(node.left,count)
        return self.recursive(node.right,count)

# %% [markdown]
# Try 2

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
import math
class Solution:
    def countNodes(self, root: Optional[TreeNode]) -> int:

       #edge case 1
       if not root : return 0

       heght = self.find_heght(root)

       # edge case 2 :
       if heght == 0 :
           return 1

       # last level in full complete tree
       upper_count = 2**heght

       # set 2 pointers left and right
       l,r = 0, upper_count-1

       # when we find the node left = right
       while l< r:
           mid = math.ceil((l+r)/2)
           print("my l,r mid for search = ", l,r , mid)

           idx_to_find = mid

           if self.find_index(root,idx_to_find,heght):
               l= idx_to_find

           else:
               r = mid-1

       print("Left index is:", l)
       return (2**heght-1) + l + 1 # because index starts from 0

    def find_heght(self,node):

        count = 0
        while node.left:
            node = node.left
            count +=1


        return count

    def find_index(self,node,idx_to_find,h):
        print("########### New Indes To Find ##########")
        count = 0 # to inceremt the levels inside the loop

        l,r = 0,((2**h)-1)
        print("h is ", h)
        while count < h:
            print(node.val)
            mid = math.ceil((l+r)/2) # recalculating mid
            print("mid is ",mid )
            print("idx_to_find is ", idx_to_find)
            if idx_to_find >= mid:
                node = node.right
                l=mid

            else:
                node = node.left


            count +=1
        if node:
            print("i return node ")
        else:
            print("i return None ")

        return node
