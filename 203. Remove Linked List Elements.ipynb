# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def removeElements(self, head, val):
        """
        :type head: ListNode
        :type val: int
        :rtype: ListNode
        """
        #edge case
        if not head:
            return None


        self.f(head,val,head)

        #edge case

        if head.val == val:
            return head.next

        return head
    def f(self,node,val,prev):
        if not node:
            return

        if node.val == val:
            prev.next = node.next
        else : prev = node

        self.f(node.next,val,prev)

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def removeElements(self, head, val):
        """
        :type head: ListNode
        :type val: int
        :rtype: ListNode
        """
        #edge case
        if not head:
            return None

        head.next = self.removeElements(head.next,val)

        return head if head.val != val else head.next
