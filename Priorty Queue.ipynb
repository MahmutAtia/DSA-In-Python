# %%
import math
class PQueue:
  def __init__(self):
    self.__heap = [15,10,5,7,3]

  def __compare(self,idx,p):
    return self.__heap[idx] > self.__heap[p]

  def __swap(self,i,j):
    temp = self.__heap[i]
    self.__heap[i] = self.__heap[j]
    self.__heap[j] = temp


  def peak(self):
    return self.__heap[0]

  def size(self):
    return len(self.__heap)

  def isEmpty(self):
    if self.__heap:
      return False
    else:
      return True

  def push(self,val):
    self.__heap.append(val)
    idx = len(self.__heap)-1
    p = (idx-1) // 2

    print(self.__heap[idx] , self.__heap[p])

    while idx>0 and self.__compare(idx,p):
      print(self.__heap)
      self.__swap (idx,p)
      idx = p
      p = math.floor((idx-1) / 2)


  def pop(self):
    self.__swap(0,self.size-1)
    root = self.__heap.pop()


    # reorder
    while

# %%
q = PQueue()

# %%
q.push(23)
# Out:
# 23 7
# [15, 10, 5, 7, 3, 20, 30, 23]
# [15, 10, 5, 23, 3, 20, 30, 7]
# [15, 23, 5, 10, 3, 20, 30, 7]
# [23, 15, 5, 10, 3, 20, 30, 7]
