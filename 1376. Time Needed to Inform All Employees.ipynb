# %% [markdown]
# Try number 1: didnt understand the problem

# %%
class Solution:
    def numOfMinutes(self, n: int, headID: int, manager: List[int], informTime: List[int]) -> int:
        mng = {}
        for i,mnger in enumerate(manager):
            if mnger == -1:
                continue
            if not mng.get(mnger):
                mng[mnger] = [i]

            else:
               li = mng[mnger]
               li.append(i)

        managers = list(mng.keys())

        #minutes for every manger
        mins = 0
        for i in managers:
            mins+=informTime[i]

        return mins

# %% [markdown]
# Try 2

# %%
class Solution:
    def numOfMinutes(self, n: int, headID: int, manager: List[int], informTime: List[int]) -> int:

        q = [headID] # the roor of the graph
        # len_q = len(q)
        seen = {}
        # level = [headID]
        levels = {}
        # count=1


        while q:

            level = []
            len_q = len(q)
            count=0

            while count<len_q:
                curr = q.pop(0)
                for emp_id , mng_id in enumerate(manager):
                    if not seen.get(mng_id) and mng_id == curr: # id we dont see the node before
                        q.append(emp_id)

                seen[curr] = True # now we saw the node and pushed its children




                count+=1 # decriment the q
                level.append(curr)

            #after while
            levels.append(level)
        for lev in levels:
            print(lev)
        # this way i have all levels, we need to calcullate max mins in every level
        total = 0
        for li in levels[:-1]:
            mins = 0
            for i in li:
                mins = max(mins,informTime[i])
                print(mins)
            print(mins, "after for")
            total+=mins

        return total

# %% [markdown]
# Try 3

# %%
class Solution:
    def numOfMinutes(self, n: int, headID: int, manager: List[int], informTime: List[int]) -> int:

        q = [headID] # the roor of the graph
        len_q = len(q)
        seen = {}
        level = [headID]
        mngs = {}
        count=1


        while q:
            curr = q.pop(0)
            mngs[curr] = []

            for emp_id , mng_id in enumerate(manager):
                if not seen.get(mng_id) and mng_id == curr: # id we dont see the node before
                    q.append(emp_id)
                    mngs[curr].append(emp_id)

            seen[curr] = True # now we saw the node and pushed its children







        # this way i have all levels
        print(mngs)
        return 1

# %% [markdown]
# Here i realized that i need a dfs approach

# %% [markdown]
# Last Try ☹

# %%
class Solution:
    def numOfMinutes(self, n: int, headID: int, manager: List[int], informTime: List[int]) -> int:
        values =[]
        total = informTime[headID]
        if headID == 0 : return 0
        self.dfs(headID,manager,informTime,values,total)
        print(values)
        return total
    def dfs(self,head,mngs,time,values,total):


        for id_emp,mng in enumerate(mngs):
            l_total = total
            if mng == head:
                self.dfs(id_emp,mngs,time,values,total)
                print(id_emp)
                values.append(id_emp)
                if time[id_emp]==0:
                    total = max(total,l_total)
                    l_total = time[head]
                    self.dfs(head,mngs,time,values,total)
                else:
                    l_total += time[id_emp]
