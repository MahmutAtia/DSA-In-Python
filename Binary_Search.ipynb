# %%
comp = 0
def search(arr,num,l,r):
  mid = (l+r) // 2
  if arr[mid] < num:
    return search(arr,num,mid+1,r)
  elif arr[mid] > num:
    return search(arr,num,l,mid-1)
  else :
    print("printed",mid)
    return mid

# %%
li = [1,2,3,4,5,6]
idx = search(li,1,0,len(li)-1)
# Out:
# printed 0

# %%
def search(arr, num, l, r):
  mid = (l + r) // 2
  if arr[mid] < num:
    return search(arr, num, mid + 1, r)
  elif arr[mid] > num:
    return search(arr, num, l, mid - 1)
  else:
    print("printed", mid)
    return mid

# %%
idx
# Out:
# 0
