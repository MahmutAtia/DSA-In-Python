# %% [markdown]
# Try 1:

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        li = []
        max_p = 1
        self.path_calc(root,li,max_p)
        print(li)
        return 3

    def path_calc(self, node,li,max_p):
        print(node.val)

        if node.left:
            max_p += 1
            self.path_calc(node.left,li,max_p)

            print("i went left and my val is :", node.val)
            print("Max p is  : ", max_p)

        li.append(node.val)
        print("max p is " , max_p)
        max_p = 1
        print("i found the val , which is:" , node.val)
        print("rest max p to", max_p)


        if node.right:
            max_p += 1
            self.path_calc(node.right,li,max_p)

            print("i went right and my val is :", node.val)
            print("Max p is  : ", max_p)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        li = []
        max_p = 0
        p = 0
        max_p = self.path_calc(root,li,max_p,p)
        print("the answer is ", max_p)
        print(li)
        return max_p

    def path_calc(self, node,li,max_p,p):
        print("the node is ", node.val)
        p+=1

        if node.left:
            self.path_calc(node.left,li,max_p,p)





        if node.right:
            self.path_calc(node.right,li,max_p,p)




        li.append(node.val)
        print("max_P : ", max_p , "p : ", p )
        max_p = max(max_p,p)
        print("maximum p is : ",max_p)
        p=0

        return max_p

# %% [markdown]
# try 3: accepted

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        li = []
        p = 0
        #edge case
        if not root:
            return 0
        self.path_calc(root,li,p)
        print(li)
        return max(li)

    def path_calc(self, node,li,p):
        print("the node is ", node.val)
        p+=1

        if node.left:
            self.path_calc(node.left,li,p)


        if node.right:
            self.path_calc(node.right,li,p)




        li.append(p)
        print("it the end! i append p : ", p)
        p=0

# %% [markdown]
# try 4 : accepted

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
            count = 0
            return self.maxDepth_calc(root,count)
    def maxDepth_calc(self,node,count):
        # print("the count begins with : " , count)


        if node == None:
            # print("count is ; " ,count)
            return count
        count+=1
        # print("iam adding 1 to count")
        return max(self.maxDepth_calc(node.left,count),self.maxDepth_calc(node.right, count))
