# %% [markdown]
# Try Number 1:

# %%
#using quick sort

def quick_sort(arr,l,r):

  idx = partion_idx(arr,l,r)
  print(l,idx,r)
  print(arr[l:idx], arr[idx], arr[idx+1:r+1])
  print(arr)

  if l<idx-1:
    quick_sort(arr,l,idx-1)

  if idx+1<r:
      quick_sort(arr,idx+1,r)


  return arr


def partion_idx(arr,l,r):

  piviot = arr[r]
  j = l
  i = l

  while j < r:
    if arr[j] < piviot:
      swap(arr,i,j)
      i+=1
      print("i updated i",i)

    j+=1 # for updating while loop

  swap(arr,i,j) # swap the piviot and i

  return i


def swap(arr,i,j):
  print("swap",j, "last i", i)
  temp = arr[i]
  arr[i] =  arr[j]
  arr[j] = temp

# %%
nums = [3,2,1,5,6,4]
quick_sort(nums,0,len(nums)-1)

# %% [markdown]
# 40 / 41

# %%
class Solution:
    def findKthLargest(self, nums: List[int], k: int) -> int:
        arr = self.quick_sort(nums,0,len(nums)-1)
        return arr[k-1]

    def quick_sort(self,arr,l,r):

        idx = self.partion_idx(arr,l,r)


        if l<idx-1:
            self.quick_sort(arr,l,idx-1)

        if idx+1<r:
            self.quick_sort(arr,idx+1,r)


        return arr


    def partion_idx(self,arr,l,r):

        piviot = arr[r]
        j = l
        i = l

        while j < r:
            if arr[j] > piviot:
                self.swap(arr,i,j)
                i+=1

            j+=1 # for updating while loop

        self.swap(arr,i,j) # swap the piviot and i

        return i


    def swap(self,arr,i,j):
        temp = arr[i]
        arr[i] =  arr[j]
        arr[j] = temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-35210f5828a3> in <cell line: 1>()
# ----> 1 class Solution:
#       2     def findKthLargest(self, nums: List[int], k: int) -> int:
#       3         arr = self.quick_sort(nums,0,len(nums)-1)
#       4         return arr[k-1]
#       5
#
# <ipython-input-32-35210f5828a3> in Solution()
#       1 class Solution:
# ----> 2     def findKthLargest(self, nums: List[int], k: int) -> int:
#       3         arr = self.quick_sort(nums,0,len(nums)-1)
#       4         return arr[k-1]
#       5
#
# NameError: name 'List' is not defined
