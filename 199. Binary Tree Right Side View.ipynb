# %% [markdown]
# Try Number 1: 37 / 216

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        # edge case
        if not root:
            return []


        li = []
        self.recursive(root,li)
        return li



    def recursive(self,node,li):
        if node:
            print(node.val)
        li.append(node.val)
        if node.right:

            self.recursive(node.right,li)

# %% [markdown]
# Try 2 BFS : accepted

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:


        # edge case
        if not root:
            return []

        # bfs way
        queue  = [root]
        out =[]


        # loop throw tree using queue
        while len(queue) > 0:
            count = 0 # of an level
            length = len(queue) # of an q
            node = None
            while count < length:
                node = queue.pop(0)

                if node.left:
                    queue.append(node.left)

                if node.right:
                    queue.append(node.right)

                count += 1
            out.append(node.val)

        return out

# %% [markdown]
# DFS solution

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        # edge case
        if not root:
            return []


        li = []
        level = 0
        self.recursive(root,li,level)
        return li



    def recursive(self,node,li,level):
        # if node:
        #     print(node.val)


        level+=1

        if level > len(li): # if the index is not exist
        #preorder right
            li.append(node.val)


        if node.right:
            self.recursive(node.right,li,level)

        #inorder right
        #li.append(node.val)

        if node.left:

            self.recursive(node.left,li,level)


        #post order right
        #li.append(node.val)
